# %% [markdown]
# # Pandas Practice Workbook — Netflix Dataset (125 Questions)
# **Prepared by Ananda Rimal** · Dataset: `netflix_titles.csv`
#
# **Columns:** `show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description`
#
# **Instructions**
# - Write your answer in the code cell **below each question**
# - Every answer must be pandas code — no manual counting
# - Sections G (GroupBy) and H (Cleaning) may need columns you create along the way — read carefully
#
# | Section | Topic | Questions |
# |---------|-------|-----------|
# | A | First Analysis of Data | 15 |
# | B | Selection with `[]`, `.loc`, `.iloc` | 25 |
# | C | Conditions (with `.loc`) | 20 |
# | D | Sorting | 10 |
# | E | Updating Data | 15 |
# | F | GroupBy | 20 |
# | G | Cleaning | 20 |
# | **Total** | | **125** |

# %% [markdown]
# ## Section A — First Analysis of Data (Q1–Q15)

# %% [markdown]
# #### Q1. Load the dataset into a DataFrame called `df` and display the first 5 rows.

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# #### Q2. Display the **last 7 rows** of the DataFrame.

# %%
# Your answer here
df.tail(7)
# Out:
#      show_id     type               title         director  \
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8801   s8802    Movie             Zinzana  Majid Al Ansari
# 8802   s8803    Movie              Zodiac    David Fincher
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
#
#                                                    cast  \
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                            country         date_added  release_year rating  \
# 8800                      Pakistan  December 15, 2016          2012  TV-PG
# 8801  United Arab Emirates, Jordan      March 9, 2016          2015  TV-MA
# 8802                 United States  November 20, 2019          2007      R
# 8803                           NaN       July 1, 2019          2018  TV-Y7
# 8804                 United States   November 1, 2019          2009      R
# 8805                 United States   January 11, 2020          2006     PG
# 8806                         India      March 2, 2019          2015  TV-14
#
#        duration                                          listed_in  \
# 8800   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 8801     96 min            Dramas, International Movies, Thrillers
# 8802    158 min                     Cult Movies, Dramas, Thrillers
# 8803  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
# 8804     88 min                            Comedies, Horror Movies
# 8805     88 min                 Children & Family Movies, Comedies
# 8806    111 min     Dramas, International Movies, Music & Musicals
#
#                                             description
# 8800  Strong-willed, middle-class Kashaf and carefre...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# #### Q3. How many rows and columns does the dataset have?

# %%
# Your answer here
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### Q4. Display the names of all columns.

# %%
# Your answer here
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %% [markdown]
# #### Q5. Use `info()` — which columns have missing values, and what is the data type of each column?

# %%
# Your answer here
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %% [markdown]
# #### Q6. Use `describe()` on the numeric columns. What is the minimum and maximum `release_year`?

# %%
# Your answer here
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# #### Q7. Use `describe(include="object")` on the text columns. Which value appears most often in the `type` column?

# %%
# Your answer here
df.describe(include="object")
#describe() method is used to generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
# It provides a quick overview of the numerical columns in the DataFrame, including count, mean, standard deviation, minimum, maximum, and quartile values. When include="object" is specified, it provides descriptive statistics for categorical columns, such as count, unique values, top value, and frequency of the top value.
# Out:
# C:\Users\Byteee\AppData\Local\Temp\ipykernel_15448\3469155017.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %% [markdown]
# #### Q8. Count the missing values in **every** column with one command.

# %%
# Your answer here
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### Q9. Which single column has the **most** missing values?

# %%
# Your answer here
a = df.isna().sum()
a.idxmax() 

#idxmax() method returns the index (row label) of the first occurrence of the maximum value in a Series.
# In this case, it identifies the column with the highest number of missing values in the DataFrame.
# Out:
# 'director'

# %% [markdown]
# #### Q10. How many **unique** values are in the `rating` column? Display them.

# %%
# Your answer here
df['rating'].unique()
# Out:
# <StringArray>
# [   'PG-13',    'TV-MA',       'PG',    'TV-14',    'TV-PG',     'TV-Y',
#     'TV-Y7',        'R',     'TV-G',        'G',    'NC-17',   '74 min',
#    '84 min',   '66 min',       'NR',        nan, 'TV-Y7-FV',       'UR']
# Length: 18, dtype: str

# %% [markdown]
# #### Q11. Show 5 **random** rows using `sample()`.

# %%
# Your answer here
df.sample()
# Out:
#      show_id     type          title director                   cast  \
# 1958   s1959  TV Show  The Chef Show      NaN  Jon Favreau, Roy Choi
#
#             country          date_added  release_year rating   duration  \
# 1958  United States  September 24, 2020          2020  TV-MA  4 Seasons
#
#        listed_in                                        description
# 1958  Docuseries  Writer, director and food enthusiast Jon Favre...

# %% [markdown]
# #### Q12. What is the memory usage of the DataFrame? (hint: `info()` or `memory_usage()`)

# %%
# Your answer here
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %% [markdown]
# #### Q13. Display the data type of only the `release_year` column.

# %%
# Your answer here
df['release_year'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Q14. Count how many titles are of each `type` using `value_counts()`.

# %%
# Your answer here
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# #### Q15. Check: does the dataset contain any **fully duplicated** rows?

# %%
# Your answer here
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Section B — Selection with `[]`, `.loc`, `.iloc` (Q16–Q40)
# *(Q16–Q30: default 0,1,2,... index · Q31–Q40: after `set_index("show_id")`)*

# %% [markdown]
# #### Q16. Select the `title` column as a **Series**.

# %%
# Your answer here
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: str

# %% [markdown]
# #### Q17. Select the `title` column as a **DataFrame** (hint: double brackets).

# %%
# Your answer here
df[['title']]
# Out:
#                       title
# 0      Dick Johnson Is Dead
# 1             Blood & Water
# 2                 Ganglands
# 3     Jailbirds New Orleans
# 4              Kota Factory
# ...                     ...
# 8802                 Zodiac
# 8803            Zombie Dumb
# 8804             Zombieland
# 8805                   Zoom
# 8806                 Zubaan
#
# [8807 rows x 1 columns]

# %% [markdown]
# #### Q18. Select the columns `title`, `type`, and `country` together.

# %%
# Your answer here
df[['title', 'type', 'country']]
# Out:
#                       title     type        country
# 0      Dick Johnson Is Dead    Movie  United States
# 1             Blood & Water  TV Show   South Africa
# 2                 Ganglands  TV Show            NaN
# 3     Jailbirds New Orleans  TV Show            NaN
# 4              Kota Factory  TV Show          India
# ...                     ...      ...            ...
# 8802                 Zodiac    Movie  United States
# 8803            Zombie Dumb  TV Show            NaN
# 8804             Zombieland    Movie  United States
# 8805                   Zoom    Movie  United States
# 8806                 Zubaan    Movie          India
#
# [8807 rows x 3 columns]

# %% [markdown]
# #### Q19. Select the first 10 rows using `.iloc`.

# %%
# Your answer here
df.iloc[0:10]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# #### Q20. Select rows with labels 10 to 20 using `.loc`. How many rows do you get and why?

# %%
# Your answer here
df.iloc[10:21]
# Out:
#    show_id     type                                              title  \
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# 12     s13    Movie                                       Je Suis Karl
# 13     s14    Movie                   Confessions of an Invisible Girl
# 14     s15  TV Show                    Crime Stories: India Detectives
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
# 20     s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
#
#                                          director  \
# 10                                            NaN
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                            NaN
# 15                                            NaN
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                            NaN
# 18                                     Adam Salky
# 19                                            NaN
# 20                                Olivier Megaton
#
#                                                  cast  \
# 10                                                NaN
# 11  Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 14                                                NaN
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...
# 16                                                NaN
# 17  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 18  Freida Pinto, Logan Marshall-Green, Robert Joh...
# 19  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
# 20                                                NaN
#
#                     country          date_added  release_year rating  \
# 10                      NaN  September 24, 2021          2021  TV-MA
# 11                      NaN  September 23, 2021          2021  TV-MA
# 12  Germany, Czech Republic  September 23, 2021          2021  TV-MA
# 13                      NaN  September 22, 2021          2021  TV-PG
# 14                      NaN  September 22, 2021          2021  TV-MA
# 15            United States  September 22, 2021          2021  TV-MA
# 16                      NaN  September 22, 2021          2020  TV-MA
# 17                   Mexico  September 22, 2021          2020  TV-MA
# 18                      NaN  September 22, 2021          2021  TV-14
# 19                      NaN  September 22, 2021          2021  TV-MA
# 20                      NaN  September 22, 2021          2021  TV-14
#
#      duration                                          listed_in  \
# 10   1 Season  Crime TV Shows, Docuseries, International TV S...
# 11   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 12    127 min                       Dramas, International Movies
# 13     91 min                 Children & Family Movies, Comedies
# 14   1 Season       British TV Shows, Crime TV Shows, Docuseries
# 15  4 Seasons                             TV Comedies, TV Dramas
# 16     67 min                Documentaries, International Movies
# 17  2 Seasons  Crime TV Shows, Spanish-Language TV Shows, TV ...
# 18     94 min                                          Thrillers
# 19   1 Season  International TV Shows, Spanish-Language TV Sh...
# 20   1 Season  Crime TV Shows, Docuseries, International TV S...
#
#                                           description
# 10  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 11  Struggling to earn a living in Bangkok, a man ...
# 12  After most of her family is murdered in a terr...
# 13  When the clever but socially-awkward Tetê join...
# 14  Cameras following Bengaluru police on the job ...
# 15  Students of color navigate the daily slights a...
# 16  Declassified documents reveal the post-WWII li...
# 17  Strangers Diego and Isabel flee their home in ...
# 18  After a deadly home invasion at a couple’s new...
# 19  In the 1960s, a Holocaust survivor joins a gro...
# 20  In the late 1970s, an accused serial rapist cl...

# %% [markdown]
# #### Q21. Using `.iloc`, select rows at positions 5 to 14 (10 rows). Compare with Q20 — why is the row count logic different?

# %%
# Your answer here
df.iloc[5:15,10:20]
# Out:
#                                             listed_in  \
# 5                  TV Dramas, TV Horror, TV Mysteries
# 6                            Children & Family Movies
# 7    Dramas, Independent Movies, International Movies
# 8                        British TV Shows, Reality TV
# 9                                    Comedies, Dramas
# 10  Crime TV Shows, Docuseries, International TV S...
# 11  Crime TV Shows, International TV Shows, TV Act...
# 12                       Dramas, International Movies
# 13                 Children & Family Movies, Comedies
# 14       British TV Shows, Crime TV Shows, Docuseries
#
#                                           description
# 5   The arrival of a charismatic young priest brin...
# 6   Equestria's divided. But a bright-eyed hero be...
# 7   On a photo shoot in Ghana, an American model s...
# 8   A talented batch of amateur bakers face off in...
# 9   A woman adjusting to life after a loss contend...
# 10  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 11  Struggling to earn a living in Bangkok, a man ...
# 12  After most of her family is murdered in a terr...
# 13  When the clever but socially-awkward Tetê join...
# 14  Cameras following Bengaluru police on the job ...

# %% [markdown]
# #### Q22. Using `.loc`, select rows 0 to 9 with only the columns `title` and `release_year`.

# %%
# df.iloc[0:5]
df.loc[0:5]
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
# Your answer here
df.loc[:9, ['title', 'release_year']]

#.loc for label-based indexing, we use row name and column name to select data
#.iloc for position-based indexing, we use row number and column number to select data.
# Out:
#                               title  release_year
# 0              Dick Johnson Is Dead          2020
# 1                     Blood & Water          2021
# 2                         Ganglands          2021
# 3             Jailbirds New Orleans          2021
# 4                      Kota Factory          2021
# 5                     Midnight Mass          2021
# 6  My Little Pony: A New Generation          2021
# 7                           Sankofa          1993
# 8     The Great British Baking Show          2021
# 9                      The Starling          2021

# %% [markdown]
# #### Q23. Using `.iloc`, select the first 8 rows and the first 5 columns.

# %%
# Your answer here
df.iloc[0:8, 0:5]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
#
#                                                 cast
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...

# %% [markdown]
# #### Q24. Using `.iloc`, select the **last row** of the DataFrame.

# %%
# Your answer here
df.iloc[[-1]]
# Out:
#      show_id   type   title     director  \
# 8806   s8807  Movie  Zubaan  Mozez Singh
#
#                                                    cast country  \
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#          date_added  release_year rating duration  \
# 8806  March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8806  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# #### Q25. Using `.iloc`, select the last 5 rows and the last 2 columns (negative positions).

# %%
# Your answer here
df.iloc[-5:, -2:]
# Out:
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# #### Q26. Using `.loc`, get the value of `title` for the row with label 50.

# %%
# Your answer here
df.loc[50,'title']
# Out:
# 'Dharmakshetra'

# %% [markdown]
# #### Q27. Using `.iloc`, get the value in row position 100, column position 2. Which column is that?

# %%
# Your answer here
df.iloc[100,2]
# Out:
# 'Tobot Galaxy Detectives'

# %% [markdown]
# #### Q28. Using `.iloc`, select every 100th row (hint: slicing with a step `::100`).

# %%
# Your answer here
df.iloc[::100]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 100     s101  TV Show                            Tobot Galaxy Detectives
# 200     s201    Movie                                    Krishna Cottage
# 300     s301    Movie                                               Vivo
# 400     s401  TV Show  Revelations: The Masters of the Universe: Reve...
# ...      ...      ...                                                ...
# 8400   s8401    Movie          The Long Goodbye: The Kara Tippetts Story
# 8500   s8501    Movie                       The Search for Life in Space
# 8600   s8601  TV Show                                              Tobot
# 8700   s8701  TV Show                                  Wartime Portraits
# 8800   s8801  TV Show                                 Zindagi Gulzar Hai
#
#                             director  \
# 0                    Kirsten Johnson
# 100                              NaN
# 200                    Santram Varma
# 300   Kirk DeMicco, Brandon Jeffords
# 400                              NaN
# ...                              ...
# 8400                       Jay Lyons
# 8500                Stephen Amezdroz
# 8600                             NaN
# 8700                             NaN
# 8800                             NaN
#
#                                                    cast  \
# 0                                                   NaN
# 100   Austin Abell, Travis Turner, Cole Howard, Anna...
# 200   Sohail Khan, Isha Koppikar, Natassha, Rati Agn...
# 300   Lin-Manuel Miranda, Ynairaly Simo, Zoe Saldana...
# 400   Kevin Smith, Tiffany Smith, Robert David, Sara...
# ...                                                 ...
# 8400                                                NaN
# 8500                                                NaN
# 8600  Octavian Kaul, Valin Shinyei, Chelsea Miller, ...
# 8700                                                NaN
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
#
#                     country          date_added  release_year rating  \
# 0             United States  September 25, 2021          2020  PG-13
# 100                     NaN   September 7, 2021          2019  TV-Y7
# 200                   India     August 27, 2021          2004  TV-14
# 300   Canada, United States      August 6, 2021          2021     PG
# 400                     NaN       July 23, 2021          2021  TV-PG
# ...                     ...                 ...           ...    ...
# 8400          United States       June 23, 2019          2019  TV-PG
# 8500          United States       April 1, 2018          2016   TV-G
# 8600                 Canada  September 11, 2019          2018  TV-Y7
# 8700                 Poland  September 15, 2016          2014  TV-MA
# 8800               Pakistan   December 15, 2016          2012  TV-PG
#
#        duration                                          listed_in  \
# 0        90 min                                      Documentaries
# 100   2 Seasons                                           Kids' TV
# 200     124 min  Action & Adventure, Horror Movies, Internation...
# 300     100 min         Children & Family Movies, Music & Musicals
# 400    1 Season         Anime Series, Stand-Up Comedy & Talk Shows
# ...         ...                                                ...
# 8400     87 min                Documentaries, Faith & Spirituality
# 8500     32 min                                      Documentaries
# 8600  2 Seasons                          Kids' TV, Korean TV Shows
# 8700   1 Season                 Docuseries, International TV Shows
# 8800   1 Season  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 100   An intergalactic device transforms toy cars in...
# 200   True love is put to the test when another woma...
# 300   A music-loving kinkajou embarks on the journey...
# 400   Take a behind-the-scenes look at “Masters of t...
# ...                                                 ...
# 8400  Faced with terminal breast cancer, a courageou...
# 8500  To determine whether we're alone in the univer...
# 8600  They’re robots that can transform into cars – ...
# 8700  Part live-action and part animation, this visu...
# 8800  Strong-willed, middle-class Kashaf and carefre...
#
# [89 rows x 12 columns]

# %% [markdown]
# #### Q29. Using `.loc`, select rows 0 to 4 and **all** columns from `title` to `country` (label slicing on columns!).

# %%
# Your answer here
df.loc[0:4,'title':'country']
# Out:
#                    title         director  \
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              NaN
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              NaN
# 4           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India

# %% [markdown]
# #### Q30. Select three specific rows by label — 3, 33, and 333 — in one `.loc` call.

# %%
# Your answer here
df.loc[[3,33,333]]
# Out:
#     show_id     type                     title     director  \
# 3        s4  TV Show     Jailbirds New Orleans          NaN
# 33      s34  TV Show                Squid Game          NaN
# 333    s334    Movie  Ferris Bueller's Day Off  John Hughes
#
#                                                   cast        country  \
# 3                                                  NaN            NaN
# 33   Lee Jung-jae, Park Hae-soo, Wi Ha-jun, Oh Youn...            NaN
# 333  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...  United States
#
#              date_added  release_year rating  duration  \
# 3    September 24, 2021          2021  TV-MA  1 Season
# 33   September 17, 2021          2021  TV-MA  1 Season
# 333      August 1, 2021          1986  PG-13   103 min
#
#                                            listed_in  \
# 3                             Docuseries, Reality TV
# 33   International TV Shows, TV Dramas, TV Thrillers
# 333            Classic Movies, Comedies, Cult Movies
#
#                                            description
# 3    Feuds, flirtations and toilet talk go down amo...
# 33   Hundreds of cash-strapped players accept a str...
# 333  After faking an illness to skip school, popula...

# %% [markdown]
# #### Q31. Set `show_id` as the index of `df` (keep it for the rest of Section B). Display the head.

# %%
# Your answer here
a = df.set_index('show_id')
a.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %% [markdown]
# #### Q32. Using `.loc`, select the row with label `"s1"`.

# %%
# Your answer here
# df.set_index('show_id', inplace=True)
df.loc[['s1']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 3
#       1 # Your answer here
#       2 # df.set_index('show_id', inplace=True)
# ----> 3 df.loc[['s1']]
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['s1'], dtype='str')] are in the [index]"

# %% [markdown]
# #### Q33. Using `.loc`, select rows `"s10"` to `"s15"`. Does label slicing still include the end?

# %%
# Your answer here
df.loc["s10" : "s15"]
# Out:
#             type                                title             director  \
# show_id
# s10        Movie                         The Starling       Theodore Melfi
# s11      TV Show  Vendetta: Truth, Lies and The Mafia                  NaN
# s12      TV Show                     Bangkok Breaking    Kongkiat Komesiri
# s13        Movie                         Je Suis Karl  Christian Schwochow
# s14        Movie     Confessions of an Invisible Girl        Bruno Garotti
# s15      TV Show      Crime Stories: India Detectives                  NaN
#
#                                                       cast  \
# show_id
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s11                                                    NaN
# s12      Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# s14      Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# s15                                                    NaN
#
#                          country          date_added  release_year rating  \
# show_id
# s10                United States  September 24, 2021          2021  PG-13
# s11                          NaN  September 24, 2021          2021  TV-MA
# s12                          NaN  September 23, 2021          2021  TV-MA
# s13      Germany, Czech Republic  September 23, 2021          2021  TV-MA
# s14                          NaN  September 22, 2021          2021  TV-PG
# s15                          NaN  September 22, 2021          2021  TV-MA
#
#          duration                                          listed_in  \
# show_id
# s10       104 min                                   Comedies, Dramas
# s11      1 Season  Crime TV Shows, Docuseries, International TV S...
# s12      1 Season  Crime TV Shows, International TV Shows, TV Act...
# s13       127 min                       Dramas, International Movies
# s14        91 min                 Children & Family Movies, Comedies
# s15      1 Season       British TV Shows, Crime TV Shows, Docuseries
#
#                                                description
# show_id
# s10      A woman adjusting to life after a loss contend...
# s11      Sicily boasts a bold "Anti-Mafia" coalition. B...
# s12      Struggling to earn a living in Bangkok, a man ...
# s13      After most of her family is murdered in a terr...
# s14      When the clever but socially-awkward Tetê join...
# s15      Cameras following Bengaluru police on the job ...

# %% [markdown]
# #### Q34. Using `.iloc`, select the row at position 0. Is it the same row as label `"s1"`?

# %%
# Your answer here
df.iloc[[0]] # yes it is
# Out:
#           type                 title         director cast        country  \
# show_id
# s1       Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#                  date_added  release_year rating duration      listed_in  \
# show_id
# s1       September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...

# %% [markdown]
# #### Q35. Using `.loc`, get the `title` and `type` of the show with id `"s500"`.

# %%
# Your answer here
df.loc[["s500"], ["title", "type"]]
# Out:
#         title     type
# show_id
# s500     Dogs  TV Show

# %% [markdown]
# #### Q36. Using `.iloc`, select the row at position 499. Is its label `"s500"`? Explain why or why not in a comment.

# %%
# Your answer here
df.iloc[[499]] 

#yes the label is s500 because the position start from 0.
# Out:
#             type title director cast        country    date_added  \
# show_id
# s500     TV Show  Dogs      NaN  NaN  United States  July 7, 2021
#
#          release_year rating   duration   listed_in  \
# show_id
# s500             2021  TV-PG  2 Seasons  Docuseries
#
#                                                description
# show_id
# s500     These six intimate stories explore the abiding...

# %% [markdown]
# #### Q37. Using `.loc`, select shows `"s1"`, `"s100"`, and `"s1000"` with columns `title` and `release_year`.

# %%
# Your answer here
df.loc[["s1", "s100","s1000"], ["title", "release_year"]]
# Out:
#                         title  release_year
# show_id
# s1       Dick Johnson Is Dead          2020
# s100             On the Verge          2021
# s1000                Stowaway          2021

# %% [markdown]
# #### Q38. What happens if you run `df.loc[0]` now? Try it, read the error, and explain in a comment.

# %%
# Your answer here
df.loc[0]
#Because we changed the index to use show_id names instead of numbers, .loc[0] fails with a KeyError because it can no longer find a row named 0

# %% [markdown]
# #### Q39. Using `.iloc`, select rows at positions [0, 99, 999] in one call.

# %%
# Your answer here
df.iloc[[0, 99, 999]]
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s100     TV Show          On the Verge              NaN
# s1000      Movie              Stowaway        Joe Penna
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s100     Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
# s1000    Anna Kendrick, Toni Collette, Daniel Dae Kim, ...
#
#                         country          date_added  release_year rating  \
# show_id
# s1                United States  September 25, 2021          2020  PG-13
# s100      France, United States   September 7, 2021          2021  TV-MA
# s1000    Germany, United States      April 22, 2021          2021  TV-MA
#
#          duration                                listed_in  \
# show_id
# s1         90 min                            Documentaries
# s100     1 Season                   TV Comedies, TV Dramas
# s1000     116 min  Dramas, International Movies, Thrillers
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s100     Four women — a chef, a single mom, an heiress ...
# s1000    A three-person crew on a mission to Mars faces...

# %% [markdown]
# #### Q40. Reset the index back to 0,1,2,... using `reset_index()`. Display the head.

# %%
# Your answer here
df.reset_index(inplace=True)

# %% [markdown]
# ## Section C — Conditions with `.loc` (Q41–Q60)
# *Write every filter with `df.loc[condition]` or `df.loc[condition, columns]` style where possible.*

# %% [markdown]
# #### Q41. Select all rows where `type` is `"Movie"`.

# %%
# Your answer here
df.loc[df["type"] == "Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 6                                                   NaN  September 24, 2021
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 6     Equestria's divided. But a bright-eyed hero be...
# 7     On a photo shoot in Ghana, an American model s...
# 9     A woman adjusting to life after a loss contend...
# 12    After most of her family is murdered in a terr...
# ...                                                 ...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [6131 rows x 12 columns]

# %% [markdown]
# #### Q42. Select all rows where `type` is `"TV Show"` — show only `title` and `country` using one `.loc` call.

# %%
# Your answer here
df.loc[df['type'] == "TV Show", ["title", "country"]]
# Out:
#                       title                                        country
# 1             Blood & Water                                   South Africa
# 2                 Ganglands                                            NaN
# 3     Jailbirds New Orleans                                            NaN
# 4              Kota Factory                                          India
# 5             Midnight Mass                                            NaN
# ...                     ...                                            ...
# 8795        Yu-Gi-Oh! Arc-V                                  Japan, Canada
# 8796             Yunus Emre                                         Turkey
# 8797              Zak Storm  United States, France, South Korea, Indonesia
# 8800     Zindagi Gulzar Hai                                       Pakistan
# 8803            Zombie Dumb                                            NaN
#
# [2676 rows x 2 columns]

# %% [markdown]
# #### Q43. Select all titles released in 2021.

# %%
# Your answer here
df.loc[df['release_year'] == 2001, ['title', 'release_year']]
# Out:
#                                                   title  release_year
# 48                                         Training Day          2001
# 54    InuYasha the Movie: Affections Touching Across...          2001
# 137                     Crocodile Dundee in Los Angeles          2001
# 168                                       Osmosis Jones          2001
# 205                   Kyo Kii... Main Jhuth Nahin Bolta          2001
# 584                              Not Another Teen Movie          2001
# 657                                            The Mole          2001
# 776                                    American Outlaws          2001
# 788                                Domestic Disturbance          2001
# 797                                            I Am Sam          2001
# 812                                           Swordfish          2001
# 995                                           Vizontele          2001
# 1019                                             Lagaan          2001
# 1121                                     Legally Blonde          2001
# 2731                           Kabhi Khushi Kabhie Gham          2001
# 3062                          Jimmy Neutron: Boy Genius          2001
# 3131                                     Dil Chahta Hai          2001
# 3910                                  Bollywood Calling          2001
# 4092                 Kevin James: Sweat the Small Stuff          2001
# 5571                                              Asoka          2001
# 5574                                         One 2 Ka 4          2001
# 5672                                           InuYasha          2001
# 5811                                 Behind Enemy Lines          2001
# 6123                                Along Came a Spider          2001
# 6163                                         Angel Eyes          2001
# 6221                                Balto 2: Wolf Quest          2001
# 6322                                    Black Hawk Down          2001
# 6337                                               Blow          2001
# 6715                                          Evolution          2001
# 6722                                        Exit Wounds          2001
# 6884                                       Gosford Park          2001
# 6949                                      Heartbreakers          2001
# 7121                     Jay and Silent Bob Strike Back          2001
# 7170                                     Kate & Leopold          2001
# 7544                       My Schoolmate, the Barbarian          2001
# 7782                           Power Rangers Time Force          2001
# 8074                                           Spy Kids          2001
# 8214   The Blue Planet: A Natural History of the Oceans          2001
# 8446                                 The Parole Officer          2001
# 8498                                          The Score          2001
# 8602                      Tom and Jerry: The Magic Ring          2001
# 8607                                      Tortilla Soup          2001
# 8623                      Tremors 3: Back to Perfection          2001
# 8768                                  Y Tu Mamá También          2001
# 8770                                            Yaadein          2001

# %% [markdown]
# #### Q44. Select all titles released **before** 2000.

# %%
# Your answer here
df.loc[df['release_year'] < 2000, ['title', 'release_year']]
# Out:
#                                     title  release_year
# 7                                 Sankofa          1993
# 22                        Avvai Shanmughi          1996
# 24                                  Jeans          1998
# 26                         Minsara Kanavu          1997
# 41                                   Jaws          1975
# ...                                   ...           ...
# 8745  Willy Wonka & the Chocolate Factory          1971
# 8748                 Winter of Our Dreams          1981
# 8763      WWII: Report from the Aleutians          1943
# 8764                           Wyatt Earp          1994
# 8792                          Young Tiger          1973
#
# [525 rows x 2 columns]

# %% [markdown]
# #### Q45. Select all titles released between 2015 and 2020 (inclusive) — two conditions with `&`.

# %%
# Your answer here
df.loc[(df['release_year'] >= 2015) & (df['release_year'] <= 2020), ['title', 'release_year']]
# Out:
#                                                   title  release_year
# 0                                  Dick Johnson Is Dead          2020
# 16    Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# 17                                      Falsa identidad          2020
# 21                               Resurrection: Ertugrul          2018
# 32                                        Sex Education          2020
# ...                                                 ...           ...
# 8796                                         Yunus Emre          2016
# 8797                                          Zak Storm          2016
# 8801                                            Zinzana          2015
# 8803                                        Zombie Dumb          2018
# 8806                                             Zubaan          2015
#
# [5624 rows x 2 columns]

# %% [markdown]
# #### Q46. Select all Movies released after 2019 (two conditions).

# %%
# Your answer here
df.loc[(df['type']=='Movie') & (df['release_year']>2019),['title','release_year']]
# Out:
#                                    title  release_year
# 0                   Dick Johnson Is Dead          2020
# 6       My Little Pony: A New Generation          2021
# 9                           The Starling          2021
# 12                          Je Suis Karl          2021
# 13      Confessions of an Invisible Girl          2021
# ...                                  ...           ...
# 3046       All the Freckles in the World          2020
# 3060                       Ghost Stories          2020
# 5972                    #cats_the_mewvie          2020
# 7594  Norm of the North: Family Vacation          2020
# 8099                         Straight Up          2020
#
# [794 rows x 2 columns]

# %% [markdown]
# #### Q47. Select all titles where `rating` is `"TV-MA"`.

# %%
# Your answer here
df['rating'].unique()
df.loc[df['rating']=='TV-MA',:]
# Out:
#      show_id     type                   title                 director  \
# 1         s2  TV Show           Blood & Water                      NaN
# 2         s3  TV Show               Ganglands          Julien Leclercq
# 3         s4  TV Show   Jailbirds New Orleans                      NaN
# 4         s5  TV Show            Kota Factory                      NaN
# 5         s6  TV Show           Midnight Mass            Mike Flanagan
# ...      ...      ...                     ...                      ...
# 8762   s8763    Movie         Wrong Side Raju            Mikhil Musale
# 8769   s8770    Movie  Y.M.I.: Yeh Mera India               N. Chandra
# 8788   s8789    Movie            You Carry Me               Ivona Juka
# 8798   s8799    Movie                Zed Plus  Chandra Prakash Dwivedi
# 8801   s8802    Movie                 Zinzana          Majid Al Ansari
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                   NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8762  Pratik Gandhi, Kimberley Louisa McBeath, Asif ...
# 8769  Anupam Kher, Atul Kulkarni, Aakash Pandey, Mil...
# 8788  Lana Baric, Vojislav Brajovic, Natasa Janjic, ...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
#
#                                     country          date_added  release_year  \
# 1                              South Africa  September 24, 2021          2021
# 2                                       NaN  September 24, 2021          2021
# 3                                       NaN  September 24, 2021          2021
# 4                                     India  September 24, 2021          2021
# 5                                       NaN  September 24, 2021          2021
# ...                                     ...                 ...           ...
# 8762                                  India     October 1, 2017          2016
# 8769                                  India       March 1, 2018          2008
# 8788  Croatia, Slovenia, Serbia, Montenegro        July 1, 2016          2015
# 8798                                  India   December 31, 2019          2014
# 8801           United Arab Emirates, Jordan       March 9, 2016          2015
#
#      rating   duration                                          listed_in  \
# 1     TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA   1 Season                             Docuseries, Reality TV
# 4     TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# ...     ...        ...                                                ...
# 8762  TV-MA    140 min                       Dramas, International Movies
# 8769  TV-MA    137 min   Dramas, Independent Movies, International Movies
# 8788  TV-MA    157 min                       Dramas, International Movies
# 8798  TV-MA    131 min             Comedies, Dramas, International Movies
# 8801  TV-MA     96 min            Dramas, International Movies, Thrillers
#
#                                             description
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# 5     The arrival of a charismatic young priest brin...
# ...                                                 ...
# 8762  The life of a chauffeur and part-time bootlegg...
# 8769  The lives of a middle-aged soap opera addict, ...
# 8788  A soap opera producer, director and makeup art...
# 8798  A philandering small-town mechanic's political...
# 8801  Recovering alcoholic Talal wakes up inside a s...
#
# [3207 rows x 12 columns]

# %% [markdown]
# #### Q48. Select all titles where `rating` is either `"PG"` or `"PG-13"` using `.isin()`.

# %%
# Your answer here
df['rating'].isin(["PG","PG-13"])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805     True
# 8806    False
# Name: rating, Length: 8807, dtype: bool

# %% [markdown]
# #### Q49. Select all titles where `rating` is **NOT** `"TV-MA"` (hint: `~` or `!=`).

# %%
# Your answer here
df.loc[df['rating']!="TV-MA",['title','rating']]
df.loc[~(df['rating']=="TV-MA"),['title','rating']]
# Out:
#                                  title rating
# 0                 Dick Johnson Is Dead  PG-13
# 6     My Little Pony: A New Generation     PG
# 8        The Great British Baking Show  TV-14
# 9                         The Starling  PG-13
# 13    Confessions of an Invisible Girl  TV-PG
# ...                                ...    ...
# 8802                            Zodiac      R
# 8803                       Zombie Dumb  TV-Y7
# 8804                        Zombieland      R
# 8805                              Zoom     PG
# 8806                            Zubaan  TV-14
#
# [5600 rows x 2 columns]

# %% [markdown]
# #### Q50. Select all titles where `country` is exactly `"India"`.

# %%
# Your answer here
df[df['country']=='India'][['title']]
# Out:
#                               title
# 4                      Kota Factory
# 24                            Jeans
# 39                     Chhota Bheem
# 50                    Dharmakshetra
# 66    Raja Rasoi Aur Anya Kahaniyan
# ...                             ...
# 8773            Yanda Kartavya Aahe
# 8775                Yeh Meri Family
# 8798                       Zed Plus
# 8799                          Zenda
# 8806                         Zubaan
#
# [972 rows x 1 columns]

# %% [markdown]
# #### Q51. Select all titles where `country` **contains** `"India"` (hint: `str.contains`, use `na=False`). Why is the row count different from the previous question?

# %%
# Your answer here
df.loc[df['country'].str.contains('India', na=False), 'title']
# Out:
# 4              Kota Factory
# 24                    Jeans
# 29                 Paranoia
# 39             Chhota Bheem
# 50            Dharmakshetra
#                ...
# 8773    Yanda Kartavya Aahe
# 8775        Yeh Meri Family
# 8798               Zed Plus
# 8799                  Zenda
# 8806                 Zubaan
# Name: title, Length: 1046, dtype: str

# %% [markdown]
# #### Q52. Select all Movies from the United States — show only `title` and `release_year`.

# %%
# Your answer here
lala = (df['type'] == 'Movie') & (df['country'].str.contains('United States', na=False))

df.loc[lala, ['title', 'release_year']]
# Out:
#                      title  release_year
# 0     Dick Johnson Is Dead          2020
# 7                  Sankofa          1993
# 9             The Starling          2021
# 27               Grown Ups          2010
# 28              Dark Skies          2013
# ...                    ...           ...
# 8791           Young Adult          2011
# 8793  Yours, Mine and Ours          2005
# 8802                Zodiac          2007
# 8804            Zombieland          2009
# 8805                  Zoom          2006
#
# [2752 rows x 2 columns]

# %% [markdown]
# #### Q53. Select all titles where `director` is missing (hint: `isna()`).

# %%
# Your answer here
df.loc[df['director'].isna(), 'title']
# Out:
# 1                             Blood & Water
# 3                     Jailbirds New Orleans
# 4                              Kota Factory
# 10      Vendetta: Truth, Lies and The Mafia
# 14          Crime Stories: India Detectives
#                        ...
# 8795                        Yu-Gi-Oh! Arc-V
# 8796                             Yunus Emre
# 8797                              Zak Storm
# 8800                     Zindagi Gulzar Hai
# 8803                            Zombie Dumb
# Name: title, Length: 2634, dtype: str

# %% [markdown]
# #### Q54. Select all titles where `director` is **not** missing.

# %%
# Your answer here
df.loc[df['director'].notna(), 'title']
# Out:
# 0                   Dick Johnson Is Dead
# 2                              Ganglands
# 5                          Midnight Mass
# 6       My Little Pony: A New Generation
# 7                                Sankofa
#                       ...
# 8801                             Zinzana
# 8802                              Zodiac
# 8804                          Zombieland
# 8805                                Zoom
# 8806                              Zubaan
# Name: title, Length: 6173, dtype: str

# %% [markdown]
# #### Q55. Select all TV Shows released in 2020 **or** 2021.

# %%
# Your answer here
hmm = (df['type'] == 'TV Show') & ((df['release_year'] == 2020) | (df['release_year'] == 2021))
df.loc[hmm, 'title']
# Out:
# 1                                   Blood & Water
# 2                                       Ganglands
# 3                           Jailbirds New Orleans
# 4                                    Kota Factory
# 5                                   Midnight Mass
#                           ...
# 3369                              BoJack Horseman
# 3433                             The Hook Up Plan
# 8125                                  Super Wings
# 8132    Surviving R. Kelly Part II: The Reckoning
# 8437                       The Netflix Afterparty
# Name: title, Length: 751, dtype: str

# %% [markdown]
# #### Q56. Select all titles whose `title` starts with the letter `"A"` (hint: `str.startswith`, `na=False`).

# %%
# Your answer here
df.loc[df['title'].str.startswith('A', na=False), 'title']
# Out:
# 22                  Avvai Shanmughi
# 30                  Ankahi Kahaniya
# 37                      Angry Birds
# 71      A StoryBots Space Adventure
# 105                Angamaly Diaries
#                    ...
# 6198            Aussie Gold Hunters
# 6199                       Automata
# 6200         Avengers: Infinity War
# 6201           Avicii: True Stories
# 6202                          Azhar
# Name: title, Length: 566, dtype: str

# %% [markdown]
# #### Q57. Select all titles whose `title` contains the word `"Love"`.

# %%
# Your answer here
df.loc[df['title'].str.contains('Love', na=False), 'title']
# Out:
# 25                Love on the Spectrum
# 158            Love Don't Cost a Thing
# 159                     Love in a Puff
# 206          LSD: Love, Sex Aur Dhokha
# 227                        Really Love
#                      ...
# 8567    The Year of Happiness and Love
# 8575                   This Is My Love
# 8649             Two Lovers and a Bear
# 8721                     What Is Love?
# 8725              What's Up With Love?
# Name: title, Length: 188, dtype: str

# %% [markdown]
# #### Q58. Using `.loc` with a condition, show the `title`, `rating`, and `release_year` of all Movies rated `"R"`.

# %%
# Your answer here
condition = (df['type'] == 'Movie') & (df['rating'] == 'R')
df.loc[condition, ['title', 'rating', 'release_year']]
# Out:
#                             title rating  release_year
# 46                     Safe House      R          2012
# 48                   Training Day      R          2001
# 81                           Kate      R          2021
# 122                    In the Cut      R          2003
# 131   Blade Runner: The Final Cut      R          1982
# ...                           ...    ...           ...
# 8765                           XX      R          2017
# 8768            Y Tu Mamá También      R          2001
# 8791                  Young Adult      R          2011
# 8802                       Zodiac      R          2007
# 8804                   Zombieland      R          2009
#
# [797 rows x 3 columns]

# %% [markdown]
# #### Q59. Count how many Movies were released after 2015 (condition + `len()` or `.shape`).

# %%
# Your answer here
count = len(df.loc[(df['type'] == 'Movie') & (df['release_year'] > 2015)])
print(count)
# Out:
# 3619

# %% [markdown]
# #### Q60. Challenge: select all Movies that are from India **or** Nepal and released after 2010 — careful with brackets around the `|` condition!

# %%
# Your answer here
df[
    ((df['country'] == 'India') | (df['country'] == 'Nepal')) & 
    (df['release_year'] > 2010)
]
# Out:
#      show_id     type                           title  \
# 4         s5  TV Show                    Kota Factory
# 39       s40  TV Show                    Chhota Bheem
# 50       s51  TV Show                   Dharmakshetra
# 66       s67  TV Show   Raja Rasoi Aur Anya Kahaniyan
# 69       s70  TV Show  Stories by Rabindranath Tagore
# ...      ...      ...                             ...
# 8771   s8772    Movie                Yaara O Dildaara
# 8772   s8773    Movie           Yamla Pagla Deewana 2
# 8775   s8776  TV Show                 Yeh Meri Family
# 8798   s8799    Movie                        Zed Plus
# 8806   s8807    Movie                          Zubaan
#
#                      director  \
# 4                         NaN
# 39                        NaN
# 50                        NaN
# 66                        NaN
# 69                        NaN
# ...                       ...
# 8771       Ksshitij Chaudhary
# 8772           Sangeeth Sivan
# 8775                      NaN
# 8798  Chandra Prakash Dwivedi
# 8806              Mozez Singh
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50    Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                  NaN   India
# 69                                                  NaN   India
# ...                                                 ...     ...
# 8771  Harbhajan Mann, Tulip Joshi, Kabir Bedi, Gulza...   India
# 8772  Dharmendra, Sunny Deol, Bobby Deol, Neha Sharm...   India
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...   India
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added  release_year rating   duration  \
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# 39    September 16, 2021          2021  TV-Y7  3 Seasons
# 50    September 15, 2021          2014  TV-PG   1 Season
# 66    September 15, 2021          2014   TV-G   1 Season
# 69    September 15, 2021          2015  TV-PG   1 Season
# ...                  ...           ...    ...        ...
# 8771    November 1, 2017          2011  TV-14    132 min
# 8772         May 1, 2017          2013  TV-14    147 min
# 8775     August 31, 2018          2018  TV-PG   1 Season
# 8798   December 31, 2019          2014  TV-MA    131 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 4     International TV Shows, Romantic TV Shows, TV ...
# 39                                             Kids' TV
# 50    International TV Shows, TV Dramas, TV Sci-Fi &...
# 66                   Docuseries, International TV Shows
# 69                    International TV Shows, TV Dramas
# ...                                                 ...
# 8771     Dramas, International Movies, Music & Musicals
# 8772  Action & Adventure, Comedies, International Mo...
# 8775                International TV Shows, TV Comedies
# 8798             Comedies, Dramas, International Movies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 4     In a city of coaching centers known to train I...
# 39    A brave, energetic little boy with superhuman ...
# 50    After the ancient Great War, the god Chitragup...
# 66    Explore the history and flavors of regional In...
# 69    The writings of Nobel Prize winner Rabindranat...
# ...                                                 ...
# 8771  The patriarch of a wealthy family with one ind...
# 8772  Up to his old tricks, con man Dharam poses as ...
# 8775  In the summer of 1998, middle child Harshu bal...
# 8798  A philandering small-town mechanic's political...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [696 rows x 12 columns]

# %% [markdown]
# ## Section D — Sorting (Q61–Q70)

# %% [markdown]
# #### Q61. Sort the DataFrame by `release_year` ascending. Show the head — what are the oldest titles?

# %%
# Your answer here
oldest_movies = df.sort_values(by='release_year', ascending=True).head()
print(oldest_movies[['title', 'release_year']])
# Out:
#                                    title  release_year
# 4250   Pioneers: First Women Filmmakers*          1925
# 7790                      Prelude to War          1942
# 8205                The Battle of Midway          1942
# 8739  Why We Fight: The Battle of Russia          1943
# 8763     WWII: Report from the Aleutians          1943

# %% [markdown]
# #### Q62. Sort by `release_year` **descending**. Show the 10 newest titles.

# %%
# Your answer here
newest_movies = df.sort_values(by='release_year', ascending=False).head(10)
print(newest_movies[['title', 'release_year']])
# Out:
#                                               title  release_year
# 1                                     Blood & Water          2021
# 2                                         Ganglands          2021
# 3                             Jailbirds New Orleans          2021
# 31                               Chicago Party Aunt          2021
# 30                                  Ankahi Kahaniya          2021
# 25                             Love on the Spectrum          2021
# 23     Go! Go! Cory Carson: Chrissy Takes the Wheel          2021
# 20  Monsters Inside: The 24 Faces of Billy Milligan          2021
# 19                                           Jaguar          2021
# 18                                        Intrusion          2021

# %% [markdown]
# #### Q63. Sort by `title` alphabetically.

# %%
# Your answer here
sorted_movies = df.sort_values(by='title', ascending=True)
print(sorted_movies[['title', 'release_year']].head())
# Out:
#                               title  release_year
# 2036                         #Alive          2020
# 2304  #AnneFrank - Parallel Stories          2019
# 2481              #FriendButMarried          2018
# 2324            #FriendButMarried 2          2020
# 5973                          #Roxy          2018

# %% [markdown]
# #### Q64. Sort by `release_year` descending AND `title` ascending at the same time (list of columns + list of ascending values).

# %%
# Your answer here
sorted_movies = df.sort_values(by=['release_year', 'title'], ascending=[False, True])
print(sorted_movies[['release_year', 'title']].head(10))
# Out:
#       release_year                            title
# 1373          2021                             50M2
# 1150          2021  7 Yards: The Chris Norton Story
# 850           2021                         99 Songs
# 851           2021                 99 Songs (Tamil)
# 852           2021                99 Songs (Telugu)
# 404           2021    9to5: The Story of a Movement
# 463           2021           A Classic Horror Story
# 683           2021                         A Family
# 452           2021                    A Perfect Fit
# 393           2021        A Second Chance:  Rivals!

# %% [markdown]
# #### `Q65. Sort by `rating`, and show only `title` and `rating` in the result.`

# %%
# Your answer here
df.sort_values(by='rating')[['title', 'rating']]
print(sorted_movies.head(10))
# Out:
#      show_id     type                            title  \
# 1373   s1374  TV Show                             50M2
# 1150   s1151    Movie  7 Yards: The Chris Norton Story
# 850     s851    Movie                         99 Songs
# 851     s852    Movie                 99 Songs (Tamil)
# 852     s853    Movie                99 Songs (Telugu)
# 404     s405    Movie    9to5: The Story of a Movement
# 463     s464    Movie           A Classic Horror Story
# 683     s684    Movie                         A Family
# 452     s453    Movie                    A Perfect Fit
# 393     s394    Movie        A Second Chance:  Rivals!
#
#                              director  \
# 1373                              NaN
# 1150                    Jonathon Link
# 850           Vishwesh Krishnamoorthy
# 851                               NaN
# 852                               NaN
# 404                               NaN
# 463   Roberto De Feo, Paolo Strippoli
# 683                   Michihito Fujii
# 452                 Hadrah Daeng Ratu
# 393                         Clay Glen
#
#                                                    cast        country  \
# 1373  Engin Öztürk, Kürşat Alnıaçık, Cengiz Bozkurt,...         Turkey
# 1150                                       Chris Norton  United States
# 850   Ehan Bhat, Edilsy Vargas, Manisha Koirala, Lis...          India
# 851                                                 NaN            NaN
# 852                                                 NaN            NaN
# 404                                                 NaN            NaN
# 463   Matilda Lutz, Francesco Russo, Peppino Mazzott...          Italy
# 683   Go Ayano, Hiroshi Tachi, Machiko Ono, Yukiya K...            NaN
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...      Indonesia
# 393   Emily Morris, Stella Shute, Eva Grados, India ...      Australia
#
#             date_added  release_year rating  duration  \
# 1373  January 27, 2021          2021  TV-MA  1 Season
# 1150    March 30, 2021          2021  TV-PG    93 min
# 850       May 21, 2021          2021  TV-14   131 min
# 851       May 21, 2021          2021  TV-14   131 min
# 852       May 21, 2021          2021  TV-14   131 min
# 404      July 22, 2021          2021  TV-MA    85 min
# 463      July 14, 2021          2021  TV-MA    95 min
# 683      June 18, 2021          2021  TV-MA   135 min
# 452      July 15, 2021          2021  TV-PG   113 min
# 393      July 23, 2021          2021     PG    91 min
#
#                                             listed_in  \
# 1373  International TV Shows, TV Dramas, TV Thrillers
# 1150                                    Documentaries
# 850    Dramas, International Movies, Music & Musicals
# 851    Dramas, International Movies, Music & Musicals
# 852    Dramas, International Movies, Music & Musicals
# 404                                     Documentaries
# 463               Horror Movies, International Movies
# 683                      Dramas, International Movies
# 452            Comedies, Dramas, International Movies
# 393           Children & Family Movies, Sports Movies
#
#                                             description
# 1373  Seeking to uncover the truth about his past, a...
# 1150  The true story of former college football play...
# 850   Challenged to compose 100 songs before he can ...
# 851   Challenged to compose 100 songs before he can ...
# 852   Challenged to compose 100 songs before he can ...
# 404   In this documentary, female office workers in ...
# 463   In this gruesome suspense film, strangers trav...
# 683   Taken in by the yakuza at a young age, Kenji s...
# 452   Sparks fly when a fashion blogger in Bali meet...
# 393   Crushed when she doesn't qualify for the Olymp...

# %% [markdown]
# #### Q66. Sort the **index** using `sort_index()` (useful after filtering).

# %%
# Your answer here
df.sort_index()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q67. Show the 5 oldest Movies (filter first, then sort, then head).

# %%
# Your answer here
oldest_movies = df[df['type'] == 'Movie'].sort_values('release_year').head(5)
print(oldest_movies)
# Out:
#      show_id   type                                          title  \
# 7790   s7791  Movie                                 Prelude to War
# 8205   s8206  Movie                           The Battle of Midway
# 8660   s8661  Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740  Movie             Why We Fight: The Battle of Russia
# 8763   s8764  Movie                WWII: Report from the Aleutians
#
#                          director                       cast        country  \
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
# 8763                  John Huston                        NaN  United States
#
#           date_added  release_year rating duration  \
# 7790  March 31, 2017          1942  TV-14   52 min
# 8205  March 31, 2017          1942  TV-14   18 min
# 8660  March 31, 2017          1943  TV-PG   61 min
# 8739  March 31, 2017          1943  TV-PG   82 min
# 8763  March 31, 2017          1943  TV-PG   45 min
#
#                           listed_in  \
# 7790  Classic Movies, Documentaries
# 8205  Classic Movies, Documentaries
# 8660  Classic Movies, Documentaries
# 8739                  Documentaries
# 8763                  Documentaries
#
#                                             description
# 7790  Frank Capra's documentary chronicles the rise ...
# 8205  Director John Ford captures combat footage of ...
# 8660  This World War II-era training film dramatizes...
# 8739  This installment of Frank Capra's acclaimed do...
# 8763  Filmmaker John Huston narrates this Oscar-nomi...

# %% [markdown]
# #### Q68. Show the 5 newest TV Shows.

# %%
# Your answer here
newest_tv_shows = df[df['type'] == 'TV Show'].sort_values('release_year', ascending=False).head(5)
print(newest_tv_shows)
# Out:
#    show_id     type                          title         director  \
# 83     s84  TV Show             Metal Shop Masters              NaN
# 5       s6  TV Show                  Midnight Mass    Mike Flanagan
# 8       s9  TV Show  The Great British Baking Show  Andy Devonshire
# 1       s2  TV Show                  Blood & Water              NaN
# 2       s3  TV Show                      Ganglands  Julien Leclercq
#
#                                                  cast         country  \
# 83                                             Jo Koy             NaN
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...             NaN
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...             NaN
#
#             date_added  release_year rating   duration  \
# 83  September 10, 2021          2021  TV-MA   1 Season
# 5   September 24, 2021          2021  TV-MA   1 Season
# 8   September 24, 2021          2021  TV-14  9 Seasons
# 1   September 24, 2021          2021  TV-MA  2 Seasons
# 2   September 24, 2021          2021  TV-MA   1 Season
#
#                                             listed_in  \
# 83                                         Reality TV
# 5                  TV Dramas, TV Horror, TV Mysteries
# 8                        British TV Shows, Reality TV
# 1     International TV Shows, TV Dramas, TV Mysteries
# 2   Crime TV Shows, International TV Shows, TV Act...
#
#                                           description
# 83  On this competition show, a group of metal art...
# 5   The arrival of a charismatic young priest brin...
# 8   A talented batch of amateur bakers face off in...
# 1   After crossing paths at a party, a Cape Town t...
# 2   To protect his family from a powerful drug lor...

# %% [markdown]
# #### `Q69. Sort by `country` and put the missing values **first** (hint: `na_position="first"`).`

# %%
# Your answer here
sorted_df = df.sort_values(by='country', na_position='first')
print(sorted_df)
# Out:
#      show_id     type                                title  \
# 2         s3  TV Show                            Ganglands
# 3         s4  TV Show                Jailbirds New Orleans
# 5         s6  TV Show                        Midnight Mass
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...      ...      ...                                  ...
# 6527   s6528    Movie                     Conjuring Spirit
# 742     s743    Movie                     Camellia Sisters
# 6816   s6817    Movie                                Furie
# 5612   s5613    Movie                    Hitler - A Career
# 2446   s2447    Movie                             Cook Off
#
#                                    director  \
# 2                           Julien Leclercq
# 3                                       NaN
# 5                             Mike Flanagan
# 6             Robert Cullen, José Luis Ucha
# 10                                      NaN
# ...                                     ...
# 6527                            Van M. Pham
# 742                       Bao Nhan, Namcito
# 6816                            Le Van Kiet
# 5612  Joachim Fest, Christian Herrendoerfer
# 2446                        Tomas Brickhill
#
#                                                    cast       country  \
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                   NaN           NaN
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...           NaN
# 10                                                  NaN           NaN
# ...                                                 ...           ...
# 6527  Phuong Mai, Quang Su, Hoang Phuc Nguyen, Chi P...       Vietnam
# 742   Le Khanh, Kaity Nguyen, Hong Van, Khuong Le, H...       Vietnam
# 6816  Ngo Thanh Van, Phan Thanh Nhien, Mai Cat Vi, T...       Vietnam
# 5612                                                NaN  West Germany
# 2446  Tendaiishe Chitima, Tendai Nguni, Jesese Mungo...      Zimbabwe
#
#               date_added  release_year rating  duration  \
# 2     September 24, 2021          2021  TV-MA  1 Season
# 3     September 24, 2021          2021  TV-MA  1 Season
# 5     September 24, 2021          2021  TV-MA  1 Season
# 6     September 24, 2021          2021     PG    91 min
# 10    September 24, 2021          2021  TV-MA  1 Season
# ...                  ...           ...    ...       ...
# 6527     August 28, 2018          2014  TV-MA   112 min
# 742        June 10, 2021          2021  TV-MA   117 min
# 6816  September 25, 2019          2019  TV-MA    97 min
# 5612   February 10, 2017          1977  TV-MA   150 min
# 2446        June 1, 2020          2017   TV-G   100 min
#
#                                               listed_in  \
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 5                    TV Dramas, TV Horror, TV Mysteries
# 6                              Children & Family Movies
# 10    Crime TV Shows, Docuseries, International TV S...
# ...                                                 ...
# 6527     Horror Movies, International Movies, Thrillers
# 742                        Dramas, International Movies
# 6816   Action & Adventure, Dramas, International Movies
# 5612                Documentaries, International Movies
# 2446    Comedies, International Movies, Romantic Movies
#
#                                             description
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 5     The arrival of a charismatic young priest brin...
# 6     Equestria's divided. But a bright-eyed hero be...
# 10    Sicily boasts a bold "Anti-Mafia" coalition. B...
# ...                                                 ...
# 6527  In the wake of her husband's betrayal, a novel...
# 742   Tensions rise and untold secrets surface for t...
# 6816  When traffickers kidnap her daughter from thei...
# 5612  This documentary examines how Adolf Hitler's t...
# 2446  Yearning for a better life, a single mother wi...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q70. What does `ascending=[False, True]` mean when sorting by two columns? Demonstrate with `release_year` and `title` and explain in a comment.

# %%
# Your answer here
sorted_movies = df.sort_values(by=['release_year', 'title'], ascending=[False, True])
print(sorted_movies)
# Out:
#      show_id     type                               title  \
# 1373   s1374  TV Show                                50M2
# 1150   s1151    Movie     7 Yards: The Chris Norton Story
# 850     s851    Movie                            99 Songs
# 851     s852    Movie                    99 Songs (Tamil)
# 852     s853    Movie                   99 Songs (Telugu)
# ...      ...      ...                                 ...
# 8763   s8764    Movie     WWII: Report from the Aleutians
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
#
#                          director  \
# 1373                          NaN
# 1150                Jonathon Link
# 850       Vishwesh Krishnamoorthy
# 851                           NaN
# 852                           NaN
# ...                           ...
# 8763                  John Huston
# 8739  Frank Capra, Anatole Litvak
# 7790                  Frank Capra
# 8205                    John Ford
# 4250                          NaN
#
#                                                    cast        country  \
# 1373  Engin Öztürk, Kürşat Alnıaçık, Cengiz Bozkurt,...         Turkey
# 1150                                       Chris Norton  United States
# 850   Ehan Bhat, Edilsy Vargas, Manisha Koirala, Lis...          India
# 851                                                 NaN            NaN
# 852                                                 NaN            NaN
# ...                                                 ...            ...
# 8763                                                NaN  United States
# 8739                                                NaN  United States
# 7790                                                NaN  United States
# 8205                          Henry Fonda, Jane Darwell  United States
# 4250                                                NaN            NaN
#
#              date_added  release_year rating  duration  \
# 1373   January 27, 2021          2021  TV-MA  1 Season
# 1150     March 30, 2021          2021  TV-PG    93 min
# 850        May 21, 2021          2021  TV-14   131 min
# 851        May 21, 2021          2021  TV-14   131 min
# 852        May 21, 2021          2021  TV-14   131 min
# ...                 ...           ...    ...       ...
# 8763     March 31, 2017          1943  TV-PG    45 min
# 8739     March 31, 2017          1943  TV-PG    82 min
# 7790     March 31, 2017          1942  TV-14    52 min
# 8205     March 31, 2017          1942  TV-14    18 min
# 4250  December 30, 2018          1925  TV-14  1 Season
#
#                                             listed_in  \
# 1373  International TV Shows, TV Dramas, TV Thrillers
# 1150                                    Documentaries
# 850    Dramas, International Movies, Music & Musicals
# 851    Dramas, International Movies, Music & Musicals
# 852    Dramas, International Movies, Music & Musicals
# ...                                               ...
# 8763                                    Documentaries
# 8739                                    Documentaries
# 7790                    Classic Movies, Documentaries
# 8205                    Classic Movies, Documentaries
# 4250                                         TV Shows
#
#                                             description
# 1373  Seeking to uncover the truth about his past, a...
# 1150  The true story of former college football play...
# 850   Challenged to compose 100 songs before he can ...
# 851   Challenged to compose 100 songs before he can ...
# 852   Challenged to compose 100 songs before he can ...
# ...                                                 ...
# 8763  Filmmaker John Huston narrates this Oscar-nomi...
# 8739  This installment of Frank Capra's acclaimed do...
# 7790  Frank Capra's documentary chronicles the rise ...
# 8205  Director John Ford captures combat footage of ...
# 4250  This collection restores films from women who ...
#
# [8807 rows x 12 columns]

# %% [markdown]
# ## Section E — Updating Data (Q71–Q85)

# %% [markdown]
# #### Q71. Rename the column `listed_in` to `genres` (keep this change).

# %%
# Your answer here
# Rename 'listed_in' to 'genres' permanently
df.rename(columns={'listed_in': 'genres'}, inplace=True)

# %% [markdown]
# #### Q72. Create a new column `age_years` = 2026 minus `release_year`.

# %%
# Your answer here
df['age_years'] = df['release_year'] - 2026

# %% [markdown]
# #### Q73. Create a column `is_movie` that is `True` when `type` is `"Movie"`.

# %%
# Your answer here
df['is_movie'] = df['type'] == 'Movie'

# %% [markdown]
# #### Q74. Create a column `is_recent` that is `True` when `release_year >= 2020`.

# %%
df['is_recent'] = df['release_year'] >= 2020

# %% [markdown]
# #### Q75. Using `.loc` with a condition, set `rating` to `"UNRATED"` for all rows where `rating` is missing.

# %%
# Your answer here
df.loc[df['rating'].isna(), 'rating'] = 'UNRATED'

# %% [markdown]
# #### Q76. Replace the value `"United States"` with `"USA"` in the `country` column (hint: `replace`).

# %%
# Your answer here
df['country'] = df['country'].replace('United States', 'USA')

# %% [markdown]
# #### Q77. Convert all titles to UPPERCASE into a new column `title_upper` (hint: `str.upper`).

# %%
df['title_upper'] = df['title'].str.upper()

# %% [markdown]
# #### Q78. Create a column `title_length` = number of characters in each title (hint: `str.len`).

# %%
# Your answer here
df['title_length'] = df['title'].str.len()

# %% [markdown]
# #### Q79. Using `.loc`, change the `title` of the row with index label 0 to `"My Favourite Show"`. Display that row to confirm.

# %%
# Your answer here
df.loc[0, 'title'] = 'My Favourite Show'
df.loc[[0]]
# Out:
#   show_id   type              title         director cast country  \
# 0      s1  Movie  My Favourite Show  Kirsten Johnson  NaN     USA
#
#            date_added  release_year rating duration         genres  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  age_years  is_movie  \
# 0  As her father nears the end of his life, filmm...         -6      True
#
#    is_recent           title_upper  title_length
# 0       True  DICK JOHNSON IS DEAD            20

# %% [markdown]
# #### Q80. Add a column `platform` where every row has the value `"Netflix"`.

# %%
# Your answer here
df['platform'] = 'Netflix'

# %% [markdown]
# #### Q81. Delete the column `title_upper` using `drop`.

# %%
# Your answer here
df.drop('title_upper', axis=1, inplace=True)

# %% [markdown]
# #### Q82. Change `release_year` to type `int32` using `astype`. Check with `dtypes`.

# %%
# Your answer here
df['release_year'] = df['release_year'].astype('int32')
print(df.dtypes)
# Out:
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int32
# rating            str
# duration          str
# genres            str
# description       str
# age_years       int64
# is_movie         bool
# is_recent        bool
# title_length    int64
# platform          str
# dtype: object

# %% [markdown]
# #### Q83. Using `.loc` with a condition, create/overwrite a column `era` = `"old"` for titles before 2010 and `"new"` for 2010 onward (two `.loc` assignments, or `np.where`).

# %%
# Your answer here
df.loc[df['release_year'] < 2010, 'era'] = 'old'
df.loc[df['release_year'] >= 2010, 'era'] = 'new'

# %% [markdown]
# #### Q84. Increase `age_years` by 1 for **all** rows in one operation.

# %%
# Your answer here
df['age_years'] = df['age_years'] + 1

# %% [markdown]
# #### Q85. Explain in a markdown comment: why is `df.loc[condition, "col"] = value` the SAFE way to update, instead of `df[condition]["col"] = value`? (SettingWithCopyWarning!)

# %%
# Your answer here

# %% [markdown]
# ## Section F — GroupBy (Q86–Q105)

# %% [markdown]
# #### Q86. Group by `type` and count the number of titles in each group (`size()`).

# %%
# Your answer here
df.groupby('type').size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %% [markdown]
# #### Q87. Group by `rating` and count titles. Which rating is most common?

# %%
# Your answer here
rating_counts = df.groupby('rating').size()
print(rating_counts)
# Out:
# rating
# 66 min         1
# 74 min         1
# 84 min         1
# G             41
# NC-17          3
# NR            80
# PG           287
# PG-13        490
# R            799
# TV-14       2160
# TV-G         220
# TV-MA       3207
# TV-PG        863
# TV-Y         307
# TV-Y7        334
# TV-Y7-FV       6
# UNRATED        4
# UR             3
# dtype: int64

# %% [markdown]
# #### Q88. Group by `release_year` and count titles. Which year had the most releases?

# %%
year_counts = df.groupby('release_year').size()
print(year_counts)
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Length: 74, dtype: int64

# %% [markdown]
# #### Q89. Group by `type` and find the **minimum** and **maximum** `release_year` for each (hint: `agg(["min","max"])`).

# %%
# Your answer here
df.groupby('type')['release_year'].agg(['min', 'max'])
# Out:
#           min   max
# type
# Movie    1942  2021
# TV Show  1925  2021

# %% [markdown]
# #### Q90. Group by `type` and compute the **average** `age_years`.

# %%
# Your answer here
df.groupby('type')['age_years'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 2
#       1 # Your answer here
# ----> 2 df.groupby('type')['age_years'].mean()
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: age_years'

# %% [markdown]
# #### Q91. Group by `country` and count titles — show only the top 10 (sort + head).

# %%
# Your answer here
top_10_countries = df["country"].value_counts().head(10)
print(top_10_countries)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %% [markdown]
# #### Q92. Group by `rating` and compute the average `title_length`.

# %%
# Your answer here
df.groupby('rating')['title_length'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 # Your answer here
# ----> 2 df.groupby('rating')['title_length'].mean()
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: title_length'

# %% [markdown]
# #### Q93. Group by `era` (from Q83) and count Movies vs TV Shows (hint: group by TWO columns).

# %%
# Your answer here
era_type_counts = pd.crosstab(df["era"], df["type"])
print(era_type_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'era'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 2
#       1 # Your answer here
# ----> 2 era_type_counts = pd.crosstab(df["era"], df["type"])
#       3 print(era_type_counts)
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'era'

# %% [markdown]
# #### Q94. Group by `type` and `rating` together and count. Display the result with `unstack()`.

# %%
# Your answer here
df.groupby(["type", "rating"])["title"].count().unstack(fill_value=0)
# Out:
# rating   66 min  74 min  84 min   G  NC-17  NR   PG  PG-13    R  TV-14  TV-G  \
# type
# Movie         1       1       1  41      3  75  287    490  797   1427   126
# TV Show       0       0       0   0      0   5    0      0    2    733    94
#
# rating   TV-MA  TV-PG  TV-Y  TV-Y7  TV-Y7-FV  UR
# type
# Movie     2062    540   131    139         5   3
# TV Show   1145    323   176    195         1   0

# %% [markdown]
# #### Q95. For Movies only: group by `release_year` and count — how many movies came out each year since 2015? (filter first, then group, then `.tail()`)

# %%
# Your answer here
df[df["type"] == "Movie"].groupby("release_year")["title"].count().tail(11)

# %% [markdown]
# #### Q96. Group by `country` and compute the average `release_year` — which 5 countries have the 'newest' catalogs on average? (sort descending, head)

# %%
# Your answer here
df.groupby("country")["release_year"].mean().sort_values(ascending=False).head(5)
# Out:
# country
# Italy, United Kingdom       2021.0
# Mauritius                   2021.0
# Belgium, United Kingdom     2021.0
# United States, Singapore    2021.0
# Mexico, France, Colombia    2021.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q97. Use `value_counts()` on `genres` — why does this NOT give clean genre counts? Explain in a comment (hint: multiple genres in one cell).

# %%
# Your answer here
df["genres"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 2
#       1 # Your answer here
# ----> 2 df["genres"].value_counts()
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'genres'

# %% [markdown]
# #### Q98. Group by `is_recent` and count — how many recent vs old titles?

# %%
# Your answer here
df.groupby("is_recent")["title"].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 2
#       1 # Your answer here
# ----> 2 df.groupby("is_recent")["title"].count()
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
#   10833             raise TypeError("You have to supply one of 'by' and 'level'")
#   10834
# > 10835         return DataFrameGroupBy(
#   10836             obj=self,
#   10837             keys=by,
#   10838             level=level,
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'is_recent'

# %% [markdown]
# #### Q99. Group by `type` and use `.agg()` with a dictionary: count of `title` and mean of `age_years` in ONE command.

# %%
# Your answer here
df.groupby("type").agg({"title": "count", "age_years": "mean"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 2
#       1 # Your answer here
# ----> 2 df.groupby("type").agg({"title": "count", "age_years": "mean"})
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:550, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     548 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     549 func = cast(AggFuncTypeDict, self.func)
# --> 550 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     552 is_non_unique_col = (
#     553     selected_obj.ndim == 2
#     554     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     555 )
#     557 if selected_obj.ndim == 1:
#     558     # key only used for output
#
# File c:\Users\Byteee\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:762, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     759     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     760     if len(cols) > 0:
#     761         # GH 58474
# --> 762         raise KeyError(f"Label(s) {list(cols)} do not exist")
#     764 aggregator_types = (list, tuple, dict)
#     766 # if we have a dict of any non-scalars
#     767 # eg. {'A' : ['mean']}, normalize all to
#     768 # be list-likes
#     769 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Label(s) ['age_years'] do not exist"

# %% [markdown]
# #### Q100. Group by `rating` and show the **number of unique countries** per rating (hint: `nunique`).

# %%
# Your answer here
df.groupby("rating")["country"].nunique()
# Out:
# rating
# 66 min        1
# 74 min        1
# 84 min        1
# G            12
# NC-17         3
# NR           31
# PG           67
# PG-13       121
# R           182
# TV-14       169
# TV-G         42
# TV-MA       314
# TV-PG       108
# TV-Y         55
# TV-Y7        60
# TV-Y7-FV      5
# UR            3
# Name: country, dtype: int64

# %% [markdown]
# #### Q101. Using `groupby` + `head(1)`, show the FIRST title (by current order) in each `type` group.

# %%
# Your answer here
df.groupby("type").head(1)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# #### Q102. Group by `release_year` and count, then plot it with `.plot()` (line chart). What trend do you see?

# %%
# Your answer here
df.groupby("release_year")["title"].count().plot(title="Titles Released Per Year")  # Trend: Exponential spike starting in the mid-2010s due to streaming growth.
# Out:
# <Axes: title={'center': 'Titles Released Per Year'}, xlabel='release_year'>

# %% [markdown]
# #### Q103. Group by `year_added`-style logic isn't possible yet — `date_added` is still text! Group by the **first 4 characters trick is wrong**. Explain in a comment why we need Section G (Cleaning) before we can group by the year a title was ADDED.

# %%
# Your answer here
df.groupby("type")["release_year"].median()
# Out:
# type
# Movie      2016.0
# TV Show    2018.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q104. Group by `type` and compute the **median** `release_year`.

# %%
# Your answer here
df.groupby("type")["release_year"].median()
# Out:
# type
# Movie      2016.0
# TV Show    2018.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q105. Challenge: for each `rating`, what percentage of titles are Movies? (hint: group by rating, compute the mean of `is_movie`, multiply by 100)

# %%
# Your answer here
(df.assign(is_movie=df["type"] == "Movie").groupby("rating")["is_movie"].mean() * 100)
# Out:
# rating
# 66 min      100.000000
# 74 min      100.000000
# 84 min      100.000000
# G           100.000000
# NC-17       100.000000
# NR           93.750000
# PG          100.000000
# PG-13       100.000000
# R            99.749687
# TV-14        66.064815
# TV-G         57.272727
# TV-MA        64.296851
# TV-PG        62.572422
# TV-Y         42.671010
# TV-Y7        41.616766
# TV-Y7-FV     83.333333
# UR          100.000000
# Name: is_movie, dtype: float64

# %% [markdown]
# ## Section G — Cleaning (Q106–Q125)

# %% [markdown]
# #### Q106. Re-check missing values per column (things changed since Section A!).

# %%
# Your answer here
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### Q107. Fill missing `director` values with `"Unknown"`.

# %%
# Your answer here
df["director"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\Byteee\AppData\Local\Temp\ipykernel_15448\2526822022.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["director"].fillna("Unknown", inplace=True)
# 0       Kirsten Johnson
# 1               Unknown
# 2       Julien Leclercq
# 3               Unknown
# 4               Unknown
#              ...
# 8802      David Fincher
# 8803            Unknown
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: str

# %% [markdown]
# #### Q108. Fill missing `cast` values with `"Unknown"`.

# %%
# Your answer here
df["cast"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\Byteee\AppData\Local\Temp\ipykernel_15448\2906758151.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["cast"].fillna("Unknown", inplace=True)
# 0                                                 Unknown
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 Unknown
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                              Unknown
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: str

# %% [markdown]
# #### Q109. Fill missing `country` values with the **most common** country (hint: `mode()[0]`).

# %%
# Your answer here
df["country"].fillna(df["country"].mode()[0], inplace=True)
# Out:
# C:\Users\Byteee\AppData\Local\Temp\ipykernel_15448\2707084109.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["country"].fillna(df["country"].mode()[0], inplace=True)
# 0       United States
# 1        South Africa
# 2       United States
# 3       United States
# 4               India
#             ...
# 8802    United States
# 8803    United States
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: str

# %% [markdown]
# #### Q110. Count the rows where `date_added` is missing, then drop those rows.

# %%
# Your answer here
missing_count = df["date_added"].isnull().sum()
print(f"Missing date_added count: {missing_count}")
df = df.dropna(subset=["date_added"])
# Out:
# Missing date_added count: 10

# %% [markdown]
# #### Q111. `date_added` has extra spaces in some rows — strip them (hint: `str.strip`).

# %%
# Your answer here
df["date_added"] = df["date_added"].str.strip()

# %% [markdown]
# #### Q112. Convert `date_added` to datetime with `pd.to_datetime`. Check the dtype after.

# %%
# Your answer here
df["date_added"] = pd.to_datetime(df["date_added"])
print(df["date_added"].dtype)
# Out:
# datetime64[us]

# %% [markdown]
# #### Q113. NOW create `year_added` = `.dt.year` and `month_added` = `.dt.month_name()`.

# %%
# Your answer here
df["year_added"] = df["date_added"].dt.year
df["month_added"] = df["date_added"].dt.month_name()

# %% [markdown]
# #### Q114. Group by `year_added` and count — which year did Netflix add the most content? (This is the question F103 could not answer!)

# %%
# Your answer here
df.groupby("year_added")["title"].count().idxmax()
# Out:
# np.int32(2019)

# %% [markdown]
# #### Q115. Group by `month_added` and count — which month is most popular for adding content?

# %%
# Your answer here
df["month_added"].value_counts().idxmax()
# Out:
# 'July'

# %% [markdown]
# #### Q116. Look at the `duration` column with `unique()` (first 20 values) — what TWO different formats do you see?

# %%
# Your answer here
df["duration"].unique()[:20]
# Out:
# <StringArray>
# [   '90 min', '2 Seasons',  '1 Season',    '91 min',   '125 min', '9 Seasons',
#    '104 min',   '127 min', '4 Seasons',    '67 min',    '94 min', '5 Seasons',
#    '161 min',    '61 min',   '166 min',   '147 min',   '103 min',    '97 min',
#    '106 min',   '111 min']
# Length: 20, dtype: str

# %% [markdown]
# #### Q117. Extract the number from `duration` into a new column `duration_int` (hint: `str.extract(r"(\\d+)")` then `astype(float)`).

# %%
# Your answer here
df["duration_int"] = df["duration"].str.extract(r"(\d+)").astype(float)

# %% [markdown]
# #### Q118. For Movies only: what is the average, minimum, and maximum duration in minutes?

# %%
# Your answer here
df[df["type"] == "Movie"]["duration_int"].agg(["mean", "min", "max"])
# Out:
# mean     99.577187
# min       3.000000
# max     312.000000
# Name: duration_int, dtype: float64

# %% [markdown]
# #### Q119. For TV Shows only: how many have more than 5 seasons? Show their titles.

# %%
# Your answer here
df[(df["type"] == "TV Show") & (df["duration_int"] > 5)]["title"]
# Out:
# 8       The Great British Baking Show
# 55                          Nailed It
# 65                       Numberblocks
# 67                  Saved by the Bell
# 82                            Lucifer
#                     ...
# 8189           The Andy Griffith Show
# 8378                       The L Word
# 8442                The Office (U.S.)
# 8557                    The West Wing
# 8710                            Weeds
# Name: title, Length: 96, dtype: str

# %% [markdown]
# #### Q120. Check duplicated **titles** (not full rows): are there any titles that appear more than once? Display them.

# %%
# Your answer here
df[df.duplicated(subset=["title"])]["title"].unique()
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %% [markdown]
# #### Q121. Are those duplicated titles real duplicates or different shows? Inspect a few with `.loc` and explain in a comment.

# %%
# Your answer here
df[df["rating"].str.contains("min", na=False)]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description  year_added  \
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...        2017
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...        2016
# 5813    Movies  The comic puts his trademark hilarious/thought...        2016
#
#      month_added  duration_int
# 5541       April           NaN
# 5794   September           NaN
# 5813      August           NaN

# %% [markdown]
# #### Q122. The `rating` column contains some WRONG values that are actually durations (like `"74 min"`) — find them (hint: `str.contains("min", na=False)`).

# %%
# Your answer here
df[df["rating"].str.contains("min", na=False)]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description  year_added  \
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...        2017
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...        2016
# 5813    Movies  The comic puts his trademark hilarious/thought...        2016
#
#      month_added  duration_int
# 5541       April           NaN
# 5794   September           NaN
# 5813      August           NaN

# %% [markdown]
# #### Q123. Fix those wrong rating rows: set their `rating` to `"UNRATED"` using `.loc`.

# %%
# Your answer here
df.loc[df["rating"].str.contains("min", na=False), "rating"] = "UNRATED"

# %% [markdown]
# #### Q124. Final check: run `info()` and `isna().sum()` — is the dataset clean now? Summarize what you fixed in a comment.

# %%
# Your answer here

# %% [markdown]
# #### Q125. Save your cleaned DataFrame to a new file `netflix_clean.csv` (without the index). This file is your submission proof!

# %%
# Your answer here
df.to_csv("netflix_clean.csv", index=False)

# %% [markdown]
# ---
# ## Submission
# - Answer **all 125 questions** — partial answers get partial marks
# - Run All must work top to bottom without errors (−5 marks if it crashes)
# - Submit BOTH files: `YourName_workbook.ipynb` and `netflix_clean.csv`
